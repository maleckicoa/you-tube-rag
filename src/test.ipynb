# %%
# from yt_dlp import YoutubeDL
# import json
# import re
# import uuid

# import json
# from pathlib import Path

import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# from langchain_chroma import Chroma
# from langchain_openai import ChatOpenAI
# from langchain_openai import OpenAIEmbeddings
# from langchain_core.documents import Document
# from langchain_text_splitters import RecursiveCharacterTextSplitter

# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.messages import HumanMessage, AIMessage
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnableParallel, RunnableLambda

# %%
#from data_loader import create_playlist_captions, embed_playlist_captions
#embed_playlist_captions(captions = "../playlist_captions.json", API_KEY = OPENAI_API_KEY)
from rag_runner import chat
#reate_playlist_captions(playlist_url = "https://www.youtube.com/playlist?list=PLD18sR-9Y-XFVCP-cSjCLr8A1B_IRsvp-")
#embed_playlist_captions(captions = "playlist_captions.json", API_KEY = OPENAI_API_KEY)

# %%
#res = chat("What are ETFs?", API_KEY = OPENAI_API_KEY)
res = chat("how good is it?", API_KEY = OPENAI_API_KEY)
# Out:
# Rewritten question: What are ETFs?. Follow-up question: could you explain in detail. Follow-up question: i still dont understand. Follow-up question: Is gold a good investment?. Follow-up question: how good is it?

# %%
res["answer"]
# Out:
# 'Gold is considered an attractive investment by many because it can help diversify a portfolio and is often viewed as a safe haven during times of economic uncertainty or inflation. However, gold does not produce any cash flow or yield, and its value can fluctuate. While some investors believe strongly in holding gold, others are more critical. Ultimately, whether gold is a "good" investment depends on your goals and risk tolerance. For more insights, you should watch the YouTube video.'

# %%
res["sources"]
# Out:
# [{'title': 'Why and How Investors Own Gold',
#   'url': 'https://www.youtube.com/watch?v=LAJnHtirHk8',
#   'id': '0216825d-4544-4269-8a35-127efc3d4b59'},
#  {'title': 'The 2025 Gold Rush - "Debasement Trade" or FOMO?',
#   'url': 'https://www.youtube.com/watch?v=3tF_lGbzCYU',
#   'id': '7cd67725-d899-4dd5-9e73-6c3ec1582101'},
#  {'title': 'Mutual Fund/ETF Keywords & What They Mean',
#   'url': 'https://www.youtube.com/watch?v=HghsQN89w9k',
#   'id': '80e02a0a-5815-4312-8e58-80e3cbc858ae'},
#  {'title': 'Covered Calls Explained - The Cost of Income',
#   'url': 'https://www.youtube.com/watch?v=R0JeJdiJc1A',
#   'id': '5b7fe9da-c71b-49bf-9f3a-56e70397d66e'},
#  {'title': 'Stock Indices & Index Fund Investing',
#   'url': 'https://www.youtube.com/watch?v=5A4lp_oZ5zg',
#   'id': 'ee0f6876-1a8f-4b3c-809f-f76c377b1eda'},
#  {'title': '2024 Finance Rewind - The Year of Trump, AI and Crypto',
#   'url': 'https://www.youtube.com/watch?v=P8Ddiwntbwc',
#   'id': 'e0cc5480-964c-4e42-89fd-71f27ff8c1a4'}]

# %%
res["history"]
# Out:
# [HumanMessage(content='What are ETFs?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='ETFs, or Exchange Traded Funds, are investment funds that can be traded on stock exchanges, similar to stocks. They often track an index, sector, or country, and their names usually indicate what they invest in. For example, the Vanguard S&P 500 ETF mimics the S&P 500 index. ETFs can be passive, simply copying an index, which allows them to operate at a lower cost and often charge lower fees. They are popular among passive investors for diversification and low costs. For more details, consider watching the YouTube video.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What are ETFs?. Follow-up question: could you explain in detail', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="ETFs, or Exchange Traded Funds, are investment funds that are traded on stock exchanges, much like individual stocks. They typically track an index, sector, or country, and this is usually reflected in their names. For example, the Vanguard S&P 500 ETF tracks the S&P 500 index, and the SPDR S&P Retail Index Fund follows the retail sector.\n\nETFs can be passive, meaning they simply mimic an index, which makes them straightforward and often lower in cost. The naming conventions of ETFs usually help investors quickly understand what the fund invests in. For instance, if an ETF tracks a specific index, sector, or country, this will be clearly listed in its name.\n\nETFs are popular because they offer diversification, can be traded easily like stocks, and often have lower fees compared to actively managed funds. However, it's important to read the fund's documents to understand costs, how closely it tracks its index, and any modifications it may have.\n\nFor a more detailed explanation, I suggest watching the YouTube video.", additional_kwargs={}, response_metadata={})]
